# %%
# Install packages
# %pip install networkx
# %pip install numpy
# %pip install tqdm
# %pip install matplotlib
# %pip install partition-networkx

# %%
# The starter code is short and simple, take a look!
from starter import *

# %% [markdown]
# # Phase 1 - Create Inputs

# %%
# Add edges with G.add_edge(u, v, weight=w)
# Idea: consider making the inputs with a solution in mind, 
# such that you know the solution when the outputs are released


def rand_list(m, n, bound, nodes):
    # Create an array of size m where
    # every element is initialized to 0
    arr = [bound] * m
    i = 0 
    upper_bound = min(10000 - (bound*m), n - (bound*m))
    while i < upper_bound:
        index = np.random.randint(bound, n) % m
        if arr[index] == nodes - 1:
            continue
        else:
            arr[index] += 1
            i += 1
    #print("hey")
    return arr

temp = rand_list(100, 50*99, 9, 100)
print(temp, sum(temp))

def deterministic(G: nx.Graph, n: int, bound:int, num_edges)-> None:
    #arr = list(np.random.randint(1,5, n//2)) + list(np.random.randint(5,10, n//4))
    #num_edges = sum(arr)
    #print("call to randlist ", n, 10000, bound, n)
    arr = list(rand_list(n, num_edges, bound, n))
    np.random.shuffle(arr)
    return arr


def general(G: nx.Graph, n, bound, num_edges):
    # TODO add edges to complete the small input
    #Set to deal with n nodes possible in graph
    normal_dist = np.random.normal(600, 300, 1000)
    positive_dist = [i for i in normal_dist if i > 0]
    positive_dist = [i for i in positive_dist if i < 1000]
    num_edges = deterministic(G, n, bound, num_edges)
    for i in range(n):
        non_i = list(range(0,i)) + list(range(i+1, n))
        num_edges_from_node = num_edges[i]
        for _ in range(num_edges_from_node):
            set_weight = int(positive_dist[np.random.randint(0, len(positive_dist))])
            target = non_i[np.random.randint(0, len(non_i))]
            non_i.remove(int(target))
            G.add_edge(i, target, weight=set_weight)


def small(G: nx.Graph):
    general(G, 100, 9, 50*99)

    
def medium(G: nx.Graph):
    general(G, 300, 6, 150*299)
    
def large(G: nx.Graph):
    general(G, 1000, 3, 500*999)

# %%
G_small = nx.empty_graph(N_SMALL)
small(G_small)
print(G_small)
visualize(G_small)
write_input(G_small, 'small.in', True)

G_med = nx.empty_graph(N_MEDIUM)
medium(G_med)
print(G_med)
visualize(G_med)
write_input(G_med, 'medium.in', True)

G_large = nx.empty_graph(N_LARGE)
large(G_large)
print(G_large)
visualize(G_large)
write_input(G_large, 'large.in', True)

# %% [markdown]
# # Phase 2 - Implement your Solver

# %%
import community as community_louvain
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import networkx as nx

#get graph from file
file_name = 'small1.in'
path = r"C:\Users\jaiwi\Desktop\Berkeley\CS 170\project-main\project-main\inputs\inputs" + "\\" + file_name
G = read_input(path)

#--------------SOLVE TEST------------------------------------------------------
# compute the best partition
partition = community_louvain.best_partition(G, resolution=0.9)

 #divide into groups
res = {}
for i, v in partition.items():
    res[v] = [i] if v not in res.keys() else res[v] + [i]
#creating the output file
num_nodes = len(G.nodes)
output_arr = [0] * num_nodes
for i in range(max(res.keys()) + 1):
    for j in res[i]:
        output_arr[j] = i


for v in range(len(output_arr)):
    if output_arr[v] < 0:
        print(output_arr[v])
    else:    
        G.nodes[v]['team'] = output_arr[v]
#--------------------------------------------------------------------------------
                
write_output(G, r"C:\Users\jaiwi\Desktop\Berkeley\CS 170\project-main\project-main\outputs\outputs" + file_name)

# %%
import community as community_louvain
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import networkx as nx
from starter import *
import random

# %%
#SOLVE WITH COMMUNITY LOUVAIN, NERGE 2 SMALLEST TOGETHER UNTIL ONLY 10 GROUPS
def solve(G: nx.Graph):
    # TODO implement this function with your solver
    # Assign a team to v with G.nodes[v]['team'] = team_id
    # Access the team of v with team_id = G.nodes[v]['team']

    # compute the best partition
    partition = community_louvain.best_partition(G, resolution=0.8)

    #divide into groups
    res = {}
    for i, v in partition.items():
        res[v] = [i] if v not in res.keys() else res[v] + [i]

    #find two smallest groups by len and merge them until only 10 groups
    while len(res.keys()) > 7:
        smallest_group = min(res.keys(), key=lambda x: len(res[x]))
        res_copy = res.copy()
        res_copy.pop(smallest_group)
        second_smallest_group = min(res_copy.keys(), key=lambda x: len(res_copy[x]))
        res[smallest_group] = res[smallest_group] + res[second_smallest_group]
        res.pop(second_smallest_group)

    #creating the output file
    num_nodes = len(G.nodes)
    output_arr = [0] * num_nodes
    for key in res.keys():
        for j in res[key]:
            output_arr[j] = key

    for v in range(len(output_arr)):
        if output_arr[v] < 0:
            print(output_arr[v])
        G.nodes[v]['team'] = output_arr[v] + 1

# %%
file_name = "large.in"
path = r"C:\Users\jaiwi\Desktop\Berkeley\CS 170\project-main\project-main\inputs\inputs" + "\\" + file_name
G = read_input(path)
visualize(G)

# %%
# def solve(G: nx.Graph):
#     # TODO implement this function with your solver
#     # Assign a team to v with G.nodes[v]['team'] = team_id
#     # Access the team of v with team_id = G.nodes[v]['team']

#     dir_dic = os.listdir(r"C:\Users\jaiwi\Desktop\Berkeley\CS 170\project-main\project-main\inputs\inputs")
    
#     print(len(dir_dic))
#     for file_name in dir_dic:

#         #print(file_name)

#         #get graph from file
#         path = r"C:\Users\jaiwi\Desktop\Berkeley\CS 170\project-main\project-main\inputs\inputs" + "\\" + file_name
#         G = read_input(path)

#         # compute the best partition
#         partition = community_louvain.best_partition(G, resolution=0.9)

#         #divide into groups
#         res = {}
#         for i, v in partition.items():
#             res[v] = [i] if v not in res.keys() else res[v] + [i]

#         #creating the output file
#         num_nodes = len(G.nodes)
#         output_arr = [0] * num_nodes
#         for i in range(max(res.keys()) + 1):
#             for j in res[i]:
#                 output_arr[j] = i

#         for v in range(len(output_arr)):
#             if output_arr[v] < 0:
#                 print(output_arr[v])
#             G.nodes[v]['team'] = output_arr[v] + 1
        
#         #file_name = file_name[:-3] + ".out"
#         #write_output(G, r"C:\Users\jaiwi\Desktop\Berkeley\CS 170\project-main\project-main\outputs\outputs" + "\\" + file_name, overwrite=True)

# #solve(G)
# #tar(r"C:\Users\jaiwi\Desktop\Berkeley\CS 170\project-main\project-main\outputs\outputs", overwrite=True)

# #print("Done")

# %%
#SOLVE WITH COMMUNITY LOUVAIN
def solve(G: nx.Graph):
    # TODO implement this function with your solver
    # Assign a team to v with G.nodes[v]['team'] = team_id
    # Access the team of v with team_id = G.nodes[v]['team']

        # compute the best partition
    partition = community_louvain.best_partition(G)

    #divide into groups
    res = {}
    for i, v in partition.items():
        res[v] = [i] if v not in res.keys() else res[v] + [i]

    #creating the output file
    num_nodes = len(G.nodes)
    output_arr = [0] * num_nodes
    for i in range(max(res.keys()) + 1):
        for j in res[i]:
            output_arr[j] = i

    for v in range(len(output_arr)):
        if output_arr[v] < 0:
            print(output_arr[v])
        G.nodes[v]['team'] = output_arr[v] + 1

# %%
#Genetic Algorithm Solution 
def solve(G: nx.Graph):
    #Set number of starter solutions
    n = 600
    #Generate n random nx.Graph solutions with teams set
    solutions = [random_solution(G) for i in range(n)]
    #Set number of generations
    generations = 20
    #Set number of solutions to keep
    keep = 60
    #Set number of solutions to mutate
    mutate = 30
    #Set number of solutions to crossover
    crossover = 30
    #Set number of solutions to generate
    generate = 500
    while generations > 0:
        #Evaluate fitness of solutions
        fitness = [fitness_function(solution) for solution in solutions]
        #Sort solutions by fitness
        solutions = [x for _,x in sorted(zip(fitness, solutions), key = lambda x: x[0])]
        #Keep best solutions
        solutions = solutions[:keep]
        print("Generation: " + str(generations) + " Fitness: " + str(fitness_function(solutions[0])))
        #Mutate solutions
        to_mutate = random.sample(range(keep), mutate)
        for i in to_mutate: 
            solutions.append(mutate_solution(solutions[i]))

        to_cross = random.sample(range(keep - 1), crossover)
        #Crossover solutions
        for i in to_cross:
           solutions.append(crossover_solution(solutions[i], solutions[i+1]))
        #Generate new solutions
        for i in range(generate):
            solutions.append(random_solution(G))
        #Decrement generations
        generations -= 1
    solutions.sort(key=fitness_function)
    best = solutions[0]
    for i in range(len(G.nodes)):
        G.nodes[i]['team'] = int(best.nodes[i]['team'])
    #print("best fitness: " + str(fitness_function(best)) + " G fitness: " + str(fitness_function(G)))
    
def fitness_function(G):
    return score(G)

def mutate_solution(G):
    G_copy = G.copy()
    #Set number of nodes to mutate
    n = len(G_copy.nodes) // 2
    #Get list of nodes
    nodes = list(G_copy.nodes)
    #Randomly select n nodes
    nodes = random.sample(nodes, n)
    #Get list of teams
    teams = list(set([G_copy.nodes[node]['team'] for node in nodes]))
    #Change team of n random nodes in G_copy to a random team
    sampled = random.sample(range(len(G_copy.nodes)), n)
    for node in sampled:
        G_copy.nodes[node]['team'] = random.choice(teams)
    return G_copy

def crossover_solution(G1, G2):
    G_copy = G1.copy()
    #Set number of nodes to crossover
    n = len(G_copy.nodes) // 2
    #Get list of nodes
    nodes = list(G_copy.nodes)
    #Randomly select n nodes
    nodes = random.sample(nodes, n)
    #Get list of teams
    teams = list(set([G_copy.nodes[node]['team'] for node in nodes]))
    #Change team of n random nodes in G_copy to a random team
    sampled = random.sample(range(len(G_copy.nodes)), n)
    for node in sampled:
        G_copy.nodes[node]['team'] = G2.nodes[node]['team']
    return G_copy

def random_solution(G):
    num_teams = np.random.randint(2, 80)
    #Create a copy of the graph
    G_copy = G.copy()
    #Get the number of nodes in the graph
    num_nodes = len(G.nodes)
    #Create an array of size num_nodes and fill it with random numbers from 0 to 9
    output_arr = np.random.randint(1, num_teams, num_nodes)
    #Assign each node in the graph a team from the array
    for v in range(len(output_arr)):
        G_copy.nodes[v]['team'] = output_arr[v]
    # print("rand")
    return G_copy

# %%
def solve(G):
    solve_group_smallest_groups(G, 10)

#Grouping the nodes into teams of x size, first starting by grouping them into groups with 0 conflict between them, then trying to make them similar sizes
def solve_size_n(G, num_teams):
    groups = find_groups(G)
    num_nodes = len(G.nodes)
    upper_bound_size = (num_nodes // num_teams) + int(0.1 * num_nodes)
    lower_bound_size = (num_nodes // num_teams) - int(0.1 * num_nodes)
    rough_size = range(lower_bound_size, upper_bound_size)
    edges = sorted(G.edges(data=True), key=lambda t: t[2].get('weight', 1))
    largest_group = max(groups, key=len)
    smallest_group = min(groups, key=len)
    while (len(largest_group) not in rough_size) and (len(smallest_group) not in rough_size):
        if len(largest_group) > upper_bound_size:
            #find the edge with the smallest weight that is in the largest group
            for edge in edges:
                if edge[0] in largest_group or edge[1] in largest_group:
                    smallest_edge = edge
                    break
            #move the smallest_edge from largest_group to the group that it connects to
            if smallest_edge[0] in largest_group:
                for group in groups:
                    if smallest_edge[1] in group:
                        group.add(smallest_edge[0])
                        largest_group.remove(smallest_edge[0])
                        break
            if smallest_edge[1] in largest_group:
                for group in groups:
                    if smallest_edge[0] in group:
                        group.add(smallest_edge[1])
                        largest_group.remove(smallest_edge[1])
                        break
        else:
            #find the edge with the smallest weight that is in the smallest group
            for edge in edges:
                if edge[0] in smallest_group or edge[1] in smallest_group:
                    smallest_edge = edge
                    break
            #move the smallest_edge from smallest_group to the group that it connects to
            if smallest_edge[0] in smallest_group:
                for group in groups:
                    if smallest_edge[1] in group:
                        group.add(smallest_edge[0])
                        smallest_group.remove(smallest_edge[0])
                        break
            else:
                for group in groups:
                    if smallest_edge[0] in group:
                        group.add(smallest_edge[1])
                        smallest_group.remove(smallest_edge[1])
                        break
    #assign the nodes to be in the same team as the group they are in
    for node in G.nodes:
        for group in groups:
            if node in group:
                G.nodes[node]['team'] = groups.index(group)
                break

#find the groups, then combinne the smallest 2 groups repeatedly until there are only num_teams groups    
def solve_group_smallest_groups(G, num_teams):
    groups = find_groups(G)
    while len(groups) > num_teams:
        smallest_group = min(groups, key=len)
        second_smallest_group = min(groups, key=lambda x: len(x) if x != smallest_group else float('inf'))
        smallest_group.update(second_smallest_group)
        groups.remove(second_smallest_group)
    for node in G.nodes:
        for group in groups:
            if node in group:
                G.nodes[node]['team'] = groups.index(group) + 1
                break

#find the groups of nodes which would have 0 conflict between them, aka no edges between them
def find_groups(G):
    groups = []
    visited = set()
    for node in G.nodes:
        if node not in visited:
            group = set()
            group.add(node)
            visited.add(node)
            for node2 in G.nodes:
                if node2 not in visited and not G.has_edge(node, node2):
                    group.add(node2)
                    visited.add(node2)
            groups.append(group)
    return groups

# %%
G = read_input('inputs/large1.in')
solve(G)
validate_output(G)
visualize(G)
score(G)

# %%
run(solve, 'small.in', 'small.out')

# %%
run_all(solve, 'smallinputs', 'outputs', overwrite=True)
tar('outputs', overwrite=True)
# Out:
#   0%|          | 0/260 [00:00<?, ?it/s]
# Generation: 7 Fitness: 303921.57326047914
# Generation: 6 Fitness: 293306.2285193469
# Generation: 5 Fitness: 293306.2285193469
# Generation: 4 Fitness: 287787.98008567153
# Generation: 3 Fitness: 287787.98008567153
# Generation: 2 Fitness: 286526.0226883295
# Generation: 1 Fitness: 284086.2285193469
#   0%|          | 1/260 [00:54<3:54:57, 54.43s/it]
# smallinputs\small1.in: cost 284086.2285193469
#   0%|          | 1/260 [01:04<4:36:43, 64.11s/it]
# Generation: 7 Fitness: 218321.01479471236
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jaiwi\Desktop\Berkeley\CS 170\project-main\project-main\main.ipynb Cell 17 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jaiwi/Desktop/Berkeley/CS%20170/project-main/project-main/main.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> run_all(solve, 'smallinputs', 'outputs', overwrite=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/jaiwi/Desktop/Berkeley/CS%20170/project-main/project-main/main.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> tar('outputs', overwrite=True)
#
# File c:\Users\jaiwi\Desktop\Berkeley\CS 170\project-main\project-main\starter.py:148, in run_all(solver, in_dir, out_dir, overwrite)
#     146 def run_all(solver, in_dir, out_dir, overwrite: bool=False):
#     147     for file in tqdm([x for x in os.listdir(in_dir) if x.endswith('.in')]):
# --> 148         run(solver, str(Path(in_dir) / file), str(Path(out_dir) / f"{file[:-len('.in')]}.out"), overwrite)
#
# File c:\Users\jaiwi\Desktop\Berkeley\CS 170\project-main\project-main\starter.py:139, in run(solver, in_file, out_file, overwrite)
#     137 def run(solver, in_file: str, out_file: str, overwrite: bool=False):
#     138     instance = read_input(in_file)
# --> 139     output = solver(instance)
#     140     if output:
#     141         instance = output
#
# c:\Users\jaiwi\Desktop\Berkeley\CS 170\project-main\project-main\main.ipynb Cell 17 in solve(G)
#      <a href='vscode-notebook-cell:/c%3A/Users/jaiwi/Desktop/Berkeley/CS%20170/project-main/project-main/main.ipynb#X21sZmlsZQ%3D%3D?line=25'>26</a> to_mutate = random.sample(range(keep), mutate)
#      <a href='vscode-notebook-cell:/c%3A/Users/jaiwi/Desktop/Berkeley/CS%20170/project-main/project-main/main.ipynb#X21sZmlsZQ%3D%3D?line=26'>27</a> for i in to_mutate:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jaiwi/Desktop/Berkeley/CS%20170/project-main/project-main/main.ipynb#X21sZmlsZQ%3D%3D?line=27'>28</a>     solutions.append(mutate_solution(solutions[i]))
#      <a href='vscode-notebook-cell:/c%3A/Users/jaiwi/Desktop/Berkeley/CS%20170/project-main/project-main/main.ipynb#X21sZmlsZQ%3D%3D?line=29'>30</a> to_cross = random.sample(range(keep - 1), crossover)
#      <a href='vscode-notebook-cell:/c%3A/Users/jaiwi/Desktop/Berkeley/CS%20170/project-main/project-main/main.ipynb#X21sZmlsZQ%3D%3D?line=30'>31</a> #Crossover solutions
#
# c:\Users\jaiwi\Desktop\Berkeley\CS 170\project-main\project-main\main.ipynb Cell 17 in mutate_solution(G)
#      <a href='vscode-notebook-cell:/c%3A/Users/jaiwi/Desktop/Berkeley/CS%20170/project-main/project-main/main.ipynb#X21sZmlsZQ%3D%3D?line=47'>48</a> def mutate_solution(G):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jaiwi/Desktop/Berkeley/CS%20170/project-main/project-main/main.ipynb#X21sZmlsZQ%3D%3D?line=48'>49</a>     G_copy = G.copy()
#      <a href='vscode-notebook-cell:/c%3A/Users/jaiwi/Desktop/Berkeley/CS%20170/project-main/project-main/main.ipynb#X21sZmlsZQ%3D%3D?line=49'>50</a>     #Set number of nodes to mutate
#      <a href='vscode-notebook-cell:/c%3A/Users/jaiwi/Desktop/Berkeley/CS%20170/project-main/project-main/main.ipynb#X21sZmlsZQ%3D%3D?line=50'>51</a>     n = len(G_copy.nodes) // 2
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\networkx\classes\graph.py:1578, in Graph.copy(self, as_view)
#    1576 G.graph.update(self.graph)
#    1577 G.add_nodes_from((n, d.copy()) for n, d in self._node.items())
# -> 1578 G.add_edges_from(
#    1579     (u, v, datadict.copy())
#    1580     for u, nbrs in self._adj.items()
#    1581     for v, datadict in nbrs.items()
#    1582 )
#    1583 return G
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\networkx\classes\graph.py:969, in Graph.add_edges_from(self, ebunch_to_add, **attr)
#     931 def add_edges_from(self, ebunch_to_add, **attr):
#     932     """Add all the edges in ebunch_to_add.
#     933
#     934     Parameters
#    (...)
#     967     >>> G.add_edges_from([(3, 4), (1, 4)], label="WN2898")
#     968     """
# --> 969     for e in ebunch_to_add:
#     970         ne = len(e)
#     971         if ne == 3:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\networkx\classes\graph.py:1578, in <genexpr>(.0)
#    1576 G.graph.update(self.graph)
#    1577 G.add_nodes_from((n, d.copy()) for n, d in self._node.items())
# -> 1578 G.add_edges_from(
#    1579     (u, v, datadict.copy())
#    1580     for u, nbrs in self._adj.items()
#    1581     for v, datadict in nbrs.items()
#    1582 )
#    1583 return G
#
# KeyboardInterrupt:
